# %%
from recommender_class_test import Recommender

# %%
r = Recommender('burgos', 'bmw', 'ciclomotor', 1987, 30)

# %%
r.recommender()
# Out:
#              city     brand                     model             type  \
# 9587       burgos       ktm                     sx_65         infantil
# 763       vizcaya       ktm                     sx_65         infantil
# 20381     navarra       ktm                     sx_65         infantil
# 14000      madrid  kawasaki                     kx_80         infantil
# 11180      madrid       ktm       50_senior_adventure         infantil
# 14585      madrid       ktm       sx_50_lc_pro_senior         infantil
# 20773   salamanca       ktm                     sx_65         infantil
# 20808   salamanca       ktm                     sx_50         infantil
# 20923       alava       bmw                  c_650_gt  scooters_+125cc
# 22778   cantabria       bmw               c_600_sport  scooters_+125cc
# 22748   cantabria       bmw               c_600_sport  scooters_+125cc
# 22708   cantabria       bmw                  c_650_gt  scooters_+125cc
# 22914   cantabria       bmw               c_600_sport  scooters_+125cc
# 22783   cantabria       bmw               c_600_sport  scooters_+125cc
# 22703   cantabria       bmw                  c_650_gt  scooters_+125cc
# 20911       alava       bmw               c_650_sport  scooters_+125cc
# 22602  valladolid       bmw                  c_650_gt  scooters_+125cc
# 758       vizcaya       bmw                  c_650_gt  scooters_+125cc
# 654       vizcaya       bmw               c_600_sport  scooters_+125cc
# 686       vizcaya       bmw                  c_650_gt  scooters_+125cc
# 920       vizcaya       bmw                  c_650_gt  scooters_+125cc
# 22673  valladolid  kawasaki  j125_special_edition_abs    scooter_125cc
# 19621   guipuzcoa       bmw                  c_650_gt  scooters_+125cc
# 19697   guipuzcoa       bmw                  c_650_gt  scooters_+125cc
# 19344   guipuzcoa       bmw                  c_650_gt  scooters_+125cc
# 19595   guipuzcoa       bmw                  c_650_gt  scooters_+125cc
# 19376   guipuzcoa       bmw                  c_650_gt  scooters_+125cc
# 20492     navarra       bmw               c_600_sport  scooters_+125cc
# 20388     navarra       bmw                  c_650_gt  scooters_+125cc
# 20317     navarra       bmw                  c_650_gt  scooters_+125cc
#
#                                  color       km  year  price  \
# 9587                           naranja     50.0  2016   3200
# 763                            naranja      1.0  2012   2200
# 20381                    not specified    200.0  2015   2999
# 14000                    not specified   1000.0  1998   1500
# 11180                          naranja      NaN  2004    999
# 14585                          naranja   1000.0  2006   1190
# 20773                  blanca-amarilla    100.0  2014   2750
# 20808                    not specified      NaN  2017   3410
# 20923                    not specified  15000.0  2012   6500
# 22778                             azul  15000.0  2014   7990
# 22748                             azul   3000.0  2015   8999
# 22708                            negro   2500.0  2015   9500
# 22914                           blanca   3300.0  2015   8500
# 22783                             azul   2900.0  2015   8999
# 22703                      marron mate   3119.0  2016   8900
# 20911                    not specified    900.0  2016  10500
# 22602                    not specified  16000.0  2012   6900
# 758                              negro  29000.0  2013   5999
# 654                              plata   2000.0  2014   8300
# 686                      not specified  14900.0  2014   7500
# 920                      not specified  13600.0  2014   7300
# 22673                               se   2000.0  2016   3400
# 19621  bronce platino metalizado - n97  40000.0  2013   5995
# 19697                             gris  17000.0  2013   7490
# 19344  bronce platino metalizado - n97  22000.0  2013   6995
# 19595    gris granito metalizado - 933  12000.0  2015   8495
# 19376          bronce metalizado - n0w    800.0  2017  10995
# 20492                            negra  19000.0  2012   6800
# 20388                             gris  35000.0  2014   6500
# 20317                marron metalizado  26000.0  2014   7990
#
#                                                      url  total_metric_pond
# 9587   http://motos.net/ocasion/ktm/sx_65/2016-en-bur...          20.500000
# 763    http://motos.net/ocasion/ktm/sx_65/2012-en-viz...          32.202584
# 20381  http://motos.net/ocasion/ktm/sx_65/2015-en-nav...          36.032255
# 14000  http://motos.net/ocasion/kawasaki/kx_80/1998-e...          39.304038
# 11180  http://motos.net/ocasion/ktm/50_senior_adventu...          40.704038
# 14585  http://motos.net/ocasion/ktm/sx_50_lc_pro_seni...          40.904038
# 20773  http://motos.net/ocasion/ktm/sx_65/2014-en-sal...          42.725753
# 20808  http://motos.net/ocasion/ktm/sx_50/2017-en-sal...          43.025753
# 20923  http://motos.net/ocasion/bmw/c_650_gt/2012-en-...          48.512047
# 22778  http://motos.net/ocasion/bmw/c_600_sport/2014-...          48.645768
# 22748  http://motos.net/ocasion/bmw/c_600_sport/2015-...          48.745768
# 22708  http://motos.net/ocasion/bmw/c_650_gt/2015-en-...          48.745768
# 22914  http://motos.net/ocasion/bmw/c_600_sport/edici...          48.745768
# 22783  http://motos.net/ocasion/bmw/c_600_sport/2015-...          48.745768
# 22703  http://motos.net/ocasion/bmw/c_650_gt/2016-en-...          48.845768
# 20911  http://motos.net/ocasion/bmw/c_650_sport/2016-...          48.912047
# 22602  http://motos.net/ocasion/bmw/c_650_gt/2012-en-...          49.993089
# 758    http://motos.net/ocasion/bmw/c_650_gt/2013-en-...          50.702584
# 654    http://motos.net/ocasion/bmw/c_600_sport/2014-...          50.802584
# 686    http://motos.net/ocasion/bmw/c_650_gt/2014-en-...          50.802584
# 920    http://motos.net/ocasion/bmw/c_650_gt/2014-en-...          50.802584
# 22673  http://motos.net/ocasion/kawasaki/j125_special...          51.193089
# 19621  http://motos.net/ocasion/bmw/c_650_gt/2013-en-...          53.715551
# 19697  http://motos.net/ocasion/bmw/c_650_gt/2013-en-...          53.715551
# 19344  http://motos.net/ocasion/bmw/c_650_gt/2013-en-...          53.715551
# 19595  http://motos.net/ocasion/bmw/c_650_gt/2015-en-...          53.915551
# 19376  http://motos.net/ocasion/bmw/c_650_gt/2017-en-...          54.115551
# 20492  http://motos.net/ocasion/bmw/c_600_sport/2012-...          54.132255
# 20388  http://motos.net/ocasion/bmw/c_650_gt/2014-en-...          54.332255
# 20317  http://motos.net/ocasion/bmw/c_650_gt/2014-en-...          54.332255

# %%
r.recommender().values.tolist()
# Out:
# [[u'barcelona',
#   u'bmw',
#   u'r_1200_c_classic',
#   u'custom',
#   u'azul',
#   27000.0,
#   2000L,
#   7500L,
#   u'http://motos.net/ocasion/bmw/r_1200_c_classic/2000-en-barcelona-6451614.htm',
#   0.0],
#  [u'barcelona',
#   u'bmw',
#   u'r_1200_c_classic',
#   u'custom',
#   u'beige',
#   114000.0,
#   1999L,
#   8790L,
#   u'http://motos.net/ocasion/bmw/r_1200_c_classic/1999-en-barcelona-6399376.htm',
#   0.1],
#  [u'barcelona',
#   u'bmw',
#   u'r_1200_c',
#   u'custom',
#   u'not specified',
#   56000.0,
#   1998L,
#   7850L,
#   u'http://motos.net/ocasion/bmw/r_1200_c/1998-en-barcelona-6395729.htm',
#   0.2],
#  [u'barcelona',
#   u'bmw',
#   u'r_1200_c_independent',
#   u'custom',
#   u'beige y azul marino',
#   49000.0,
#   2004L,
#   8000L,
#   u'http://motos.net/ocasion/bmw/r_1200_c_independent/2004-en-barcelona-6369401.htm',
#   0.4],
#  [u'barcelona',
#   u'bmw',
#   u'r_1200_c_montauk',
#   u'custom',
#   u'negro',
#   21000.0,
#   2004L,
#   10500L,
#   u'http://motos.net/ocasion/bmw/r_1200_c_montauk/2004-en-barcelona-6452494.htm',
#   0.4],
#  [u'barcelona',
#   u'bmw',
#   u'r_1100_r',
#   u'naked',
#   u'not specified',
#   124000.0,
#   2000L,
#   2750L,
#   u'http://motos.net/ocasion/bmw/r_1100_r/2000-en-barcelona-6377335.htm',
#   8.0],
#  [u'barcelona',
#   u'bmw',
#   u'r_850_r',
#   u'naked',
#   u'negre',
#   111000.0,
#   2000L,
#   2500L,
#   u'http://motos.net/ocasion/bmw/r_850_r/2000-en-barcelona-6391489.htm',
#   8.0],
#  [u'barcelona',
#   u'bmw',
#   u'r_1100_r',
#   u'naked',
#   u'gris grafito',
#   81000.0,
#   1999L,
#   3000L,
#   u'http://motos.net/ocasion/bmw/r_1100_r/1999-en-barcelona-6386325.htm',
#   8.1],
#  [u'barcelona',
#   u'bmw',
#   u'r_1150_r',
#   u'naked',
#   u'granate',
#   62000.0,
#   2002L,
#   4500L,
#   u'http://motos.net/ocasion/bmw/r_1150_r/2002-en-barcelona-6395730.htm',
#   8.2],
#  [u'barcelona',
#   u'bmw',
#   u'r_1150_r',
#   u'naked',
#   u'not specified',
#   80904.0,
#   2002L,
#   4500L,
#   u'http://motos.net/ocasion/bmw/r_1150_r/2002-en-barcelona-6436092.htm',
#   8.2],
#  [u'barcelona',
#   u'bmw',
#   u'r_850_r',
#   u'naked',
#   u'plata',
#   79080.0,
#   1998L,
#   2850L,
#   u'http://motos.net/ocasion/bmw/r_850_r/1998-en-barcelona-6397385.htm',
#   8.2],
#  [u'barcelona',
#   u'bmw',
#   u'r_1100_r',
#   u'naked',
#   u'granate',
#   125000.0,
#   1998L,
#   3000L,
#   u'http://motos.net/ocasion/bmw/r_1100_r/1998-en-barcelona-6428256.htm',
#   8.2],
#  [u'barcelona',
#   u'bmw',
#   u'r_1100_r',
#   u'naked',
#   u'verde',
#   103000.0,
#   1998L,
#   3000L,
#   u'http://motos.net/ocasion/bmw/r_1100_r/1998-en-barcelona-6380395.htm',
#   8.2],
#  [u'barcelona',
#   u'bmw',
#   u'r_850_r',
#   u'naked',
#   u'plata',
#   90000.0,
#   2002L,
#   3100L,
#   u'http://motos.net/ocasion/bmw/r_850_r/2002-en-barcelona-6353897.htm',
#   8.2],
#  [u'barcelona',
#   u'bmw',
#   u'r_1150_r',
#   u'naked',
#   u'rojo',
#   32879.0,
#   2003L,
#   5190L,
#   u'http://motos.net/ocasion/bmw/r_1150_r/2003-en-barcelona-6438911.htm',
#   8.3],
#  [u'barcelona',
#   u'bmw',
#   u'r_850_r',
#   u'naked',
#   u'gris',
#   72000.0,
#   2003L,
#   5000L,
#   u'http://motos.net/ocasion/bmw/r_850_r/2003-en-barcelona-6423950.htm',
#   8.3],
#  [u'barcelona',
#   u'bmw',
#   u'r_1100_r',
#   u'naked',
#   u'verde',
#   59000.0,
#   1997L,
#   3300L,
#   u'http://motos.net/ocasion/bmw/r_1100_r/1997-en-barcelona-6396279.htm',
#   8.3],
#  [u'barcelona',
#   u'bmw',
#   u'r_850_r',
#   u'naked',
#   u'azul',
#   45000.0,
#   1997L,
#   3500L,
#   u'http://motos.net/ocasion/bmw/r_850_r/1997-en-barcelona-6298994.htm',
#   8.3],
#  [u'barcelona',
#   u'bmw',
#   u'r_1150_r',
#   u'naked',
#   u'negro',
#   29900.0,
#   2003L,
#   4900L,
#   u'http://motos.net/ocasion/bmw/r_1150_r/2003-en-barcelona-6421142.htm',
#   8.3],
#  [u'barcelona',
#   u'bmw',
#   u'r_1150_r',
#   u'naked',
#   u'negro',
#   46500.0,
#   2003L,
#   4250L,
#   u'http://motos.net/ocasion/bmw/r_1150_r/2003-en-barcelona-6453893.htm',
#   8.3],
#  [u'barcelona',
#   u'bmw',
#   u'r_850_r',
#   u'naked',
#   u'plata',
#   81200.0,
#   2003L,
#   4800L,
#   u'http://motos.net/ocasion/bmw/r_850_r/2003-en-barcelona-6443905.htm',
#   8.3],
#  [u'barcelona',
#   u'bmw',
#   u'r_1150_r',
#   u'naked',
#   u'azul',
#   107000.0,
#   2003L,
#   3800L,
#   u'http://motos.net/ocasion/bmw/r_1150_r/2003-en-barcelona-6398301.htm',
#   8.3],
#  [u'barcelona',
#   u'bmw',
#   u'r_850_r',
#   u'naked',
#   u'gris',
#   79000.0,
#   2004L,
#   4250L,
#   u'http://motos.net/ocasion/bmw/r_850_r/2004-en-barcelona-6433243.htm',
#   8.4],
#  [u'barcelona',
#   u'bmw',
#   u'r_850_r',
#   u'naked',
#   u'not specified',
#   145000.0,
#   2004L,
#   3000L,
#   u'http://motos.net/ocasion/bmw/r_850_r/2004-en-barcelona-6428906.htm',
#   8.4],
#  [u'barcelona',
#   u'bmw',
#   u'r_850_r',
#   u'naked',
#   u'gris plata',
#   89000.0,
#   2004L,
#   4500L,
#   u'http://motos.net/ocasion/bmw/r_850_r/2004-en-barcelona-6465738.htm',
#   8.4],
#  [u'barcelona',
#   u'bmw',
#   u'r_1150_r',
#   u'naked',
#   u'negro',
#   54000.0,
#   2004L,
#   4900L,
#   u'http://motos.net/ocasion/bmw/r_1150_r/2004-en-barcelona-6450313.htm',
#   8.4],
#  [u'barcelona',
#   u'bmw',
#   u'r_850_r',
#   u'naked',
#   u'plata',
#   66000.0,
#   2005L,
#   4000L,
#   u'http://motos.net/ocasion/bmw/r_850_r/2005-en-barcelona-6433815.htm',
#   8.5],
#  [u'barcelona',
#   u'bmw',
#   u'r_1150_r',
#   u'naked',
#   u'gris metalizado',
#   125000.0,
#   2005L,
#   3300L,
#   u'http://motos.net/ocasion/bmw/r_1150_r/2005-en-barcelona-6381676.htm',
#   8.5],
#  [u'barcelona',
#   u'bmw',
#   u'r_850_r',
#   u'naked',
#   u'plata',
#   66000.0,
#   2005L,
#   4250L,
#   u'http://motos.net/ocasion/bmw/r_850_r/2005-en-barcelona-6439521.htm',
#   8.5],
#  [u'barcelona',
#   u'bmw',
#   u'k_1200_r',
#   u'naked',
#   u'negra',
#   35000.0,
#   2005L,
#   6000L,
#   u'http://motos.net/ocasion/bmw/k_1200_r/2005-en-barcelona-6392049.htm',
#   8.5]]

# %%
import pandas as pd
df_motos_raw = pd.read_csv('scraped_data/motos_raw_data.csv', sep=';')
df_motos_raw.shape
# Out:
# (26511, 10)

# %%
df_motos_raw['color'].fillna('not specified', inplace=True)

# %%
df_motos_raw.shape
# Out:
# (26511, 10)

# %% [markdown]
# Data cleaning

# %%
# Convert the dataframe to lower case
df_motos_raw = df_motos_raw.apply(lambda x: x.astype(str).str.lower())

# %%
#Join the words in the 'model' and 'type' fields with an underscore
df_motos_raw['model'] = df_motos_raw['model'].str.replace(' ', '_')
df_motos_raw['type'] = df_motos_raw['type'].str.replace(' ', '_')

# %%
# Looking for duplicates
df_motos_raw['is_duplicated'] = df_motos_raw.duplicated()
duplicates = df_motos_raw['is_duplicated'].sum()
print '%d duplicates' %duplicates
# Out:
# 93 duplicates

# %%
# Removing duplicates and delete 'is_duplicated' column
df_motos_raw = df_motos_raw.loc[df_motos_raw['is_duplicated']==False]
df_motos_raw = df_motos_raw.drop('is_duplicated', 1)
df_motos_raw.shape
# Out:
# (26418, 10)

# %%
# Lets investigate column by column the NaNs we have in the dataframe
for column in df_motos_raw.columns:
    n_nan = df_motos_raw[column]=='nan'
    print column + " %d -- > %f" %(n_nan.sum(), (n_nan.sum()*1.0)/df_motos_raw.shape[0]*100)
# Out:
# city 0 -- > 0.000000
# brand 0 -- > 0.000000
# model 0 -- > 0.000000
# type 0 -- > 0.000000
# cc 95 -- > 0.359603
# color 0 -- > 0.000000
# km 1631 -- > 6.173821
# year 0 -- > 0.000000
# price 0 -- > 0.000000
# url 0 -- > 0.000000

# %%
# Lets investigate the unique values we have in the columns
for column in ['city', 'brand', 'model', 'type', 'color', 'year']:
    column_uv = df_motos_raw[column].unique()
    print column + " --> " + "%d unique values" %len(sorted(column_uv))
# Out:
# city --> 52 unique values
# brand --> 148 unique values
# model --> 3011 unique values
# type --> 15 unique values
# color --> 1923 unique values
# year --> 48 unique values

# %% [markdown]
# Merge some data

# %%
#In order to calculate our first metric, we will use the following columns:
# "lon" and "lat" : These are the longitude and latitude of the corresponding city. We will add them later.
# "brand", "model", "type", "year"

# %%
# Calculating the longitude and latitude of the cities
import geopy
from geopy.geocoders import Nominatim
geolocator = Nominatim()

# %%
cities = df_motos_raw['city'].unique()
locations_rows = []
for city in cities:
    location = geolocator.geocode([city], timeout = 15)
    locations_rows.append([city, location.latitude, location.longitude])
#Save into a csv
df_locations = pd.DataFrame(locations_rows, columns = ['city', 'lat', 'lon'])
#df_locations.to_csv('auxiliary_data/locations_coords.csv', index = False)

# %%
df_locations.head(3)
# Out:
#       city        lat       lon
# 0   madrid  40.416705 -3.703582
# 1  navarra  42.612549 -1.830791
# 2  granada  37.183020 -3.602192

# %%
# Merge df_locations with df_motos_raw
df_motos_raw_coord = pd.merge(df_motos_raw, df_locations, on = 'city')
#Save into a csv
#df_motos_raw_coord.to_csv('df_motos_raw_coord.csv', index = False)

# %%
# We have created two csv files with a rank for the motos brands and types
# called rank_motos_brands.csv and rank_motos_types.csv

# With the first one, rank_motos_brands.csv, we are gint to create another  column, with a score to the corresponding brand
df_rank_moto_brand = pd.read_csv('scraped_data/rank_moto_brands.csv', sep=';')
df_motos_raw_coord_brand = pd.merge(df_motos_raw_coord, df_rank_moto_brand, on = 'brand', how = 'left')
#If the brand does not exist, the rank value will be zero
#!!OJO, AÑADIR MARCAS DE MOTOS QUE FALTAN ANTES DE PONER UN CERO!!!!!!!!!!!!!!!!!
df_motos_raw_coord_brand.brand_score.fillna(0, inplace=True)
# Save into a csv
df_motos_raw_coord_brand.to_csv('df_motos_coord_brand.csv', index = False)

# With the second one, rank_moto_types.csv, we are going to create another column, with a score to the corresponding type
df_rank_moto_type = pd.read_csv('auxiliary_data/rank_moto_types.csv', sep=';')
df_motos_raw_coord_brand_types = pd.merge(df_motos_raw_coord_brand, df_rank_moto_type, on = 'type', how = 'left')
#Save into a csv
df_motos_raw_coord_brand_types.to_csv('df_motos_raw_coord_brand_type.csv', index = False)

# %%
df_motos_raw_coord_brand_types.head(3)
# Out:
#      city   brand                model             type      cc   color  \
# 0  madrid     bmw            r_1200_gs            trail  1170.0    rojo
# 1  madrid  ducati         monster_696+            naked   696.0  blanco
# 2  madrid   kymco  super_dink_300i_abs  scooters_+125cc   299.0  blanco
#
#         km  year price                                                url  \
# 0  57400.0  2004  7490  http://motos.net/ocasion/bmw/r_1200_gs/2004-en...
# 1  18166.0  2011  5999  http://motos.net/ocasion/ducati/monster_696/20...
# 2   9644.0  2011  3299  http://motos.net/ocasion/kymco/super_dink_300i...
#
#          lat       lon  brand_score  type_score  city_metric  brand_metric  \
# 0  40.416705 -3.703582        356.0         230          0.0             0
# 1  40.416705 -3.703582        473.0         260          0.0           117
# 2  40.416705 -3.703582         37.0         120          0.0           319
#
#    type_metric  year_metric  total_metric_pond
# 0           50            4               20.4
# 1           20           11               55.9
# 2          160           11              192.7

# %%
sorted(df_motos_raw_coord_brand_types.brand.unique())
# Out:
# ['adly',
#  'aeon',
#  'aiyumo',
#  'ajp',
#  'alpina renania',
#  'american ironhorse',
#  'apollo orion',
#  'aprilia',
#  'arctic cat',
#  'azel',
#  'benelli',
#  'beta',
#  'big dog',
#  'bimota',
#  'bmw',
#  'brammo',
#  'brp',
#  'btm',
#  'buell',
#  'bultaco',
#  'cagiva',
#  'can-am',
#  'cfmoto',
#  'chopper nation',
#  'clipic',
#  'cooltra',
#  'cpi',
#  'csr',
#  'daelim',
#  'dak',
#  'derbi',
#  'dh haotian',
#  'dorton',
#  'ducati',
#  'e-max',
#  'elmoto',
#  'fantic',
#  'fb mondial',
#  'gas gas',
#  'generic',
#  'gilera',
#  'goes',
#  'govecs',
#  'gowinn',
#  'hammel',
#  'hanway',
#  'harley davidson',
#  'hm',
#  'honda',
#  'hsun',
#  'hudson boss',
#  'husaberg',
#  'husqvarna',
#  'hyosung',
#  'i-moto',
#  'imr',
#  'indian',
#  'innocenti',
#  'italjet',
#  'jianshe',
#  'jin lun',
#  'jonway',
#  'kangxin',
#  'kawasaki',
#  'keeway',
#  'kenrod',
#  'kinroad',
#  'ksr moto',
#  'ktm',
#  'kymco',
#  'lambretta',
#  'lanvertti',
#  'lectric',
#  'lem',
#  'lemev',
#  'leonart',
#  'lifan',
#  'linhai',
#  'lml',
#  'macbor',
#  'malaguti',
#  'mash',
#  'mbk',
#  'mecatecno',
#  'megelli',
#  'mobilette',
#  'monkey bike',
#  'montesa',
#  'moto guzzi',
#  'moto morini',
#  'motogac',
#  'motor hispania',
#  'mtm',
#  'mtr',
#  'muz',
#  'mv agusta',
#  'mxonda',
#  'orcal',
#  'orion',
#  'oset',
#  'ossa',
#  'peugeot',
#  'piaggio',
#  'polini',
#  'puch',
#  'qingqi',
#  'quadro',
#  'rav',
#  'rebel',
#  'renault',
#  'ridley motorcycles',
#  'rieju',
#  'riya',
#  'roan',
#  'royal enfield',
#  'samada',
#  'scomadi',
#  'scorpa',
#  'sherco',
#  'sumco',
#  'sumo',
#  'suzuki',
#  'sym',
#  'tbq',
#  'tgb',
#  'tm',
#  'torrot',
#  'triumph',
#  'ural',
#  'vertigo',
#  'vespa',
#  'vespino',
#  'via scooter',
#  'victory',
#  'vmoto',
#  'vor',
#  'wildlander',
#  'wottan',
#  'xingyue',
#  'xmotos',
#  'yamaha',
#  'ycf',
#  'young rider',
#  'zero',
#  'zero motorcycles',
#  'zms motors',
#  'znen',
#  'zongshen']

# %%
# OK!, so we have a first version of the data we will use to recommend vehicles
# df_motos_raw_coord_brand_types
# Lets try to calculate the metric only with some fields. We are going to add these distances:
# cities distance, brand_distance, type_distance, year_distance
# We need to create some functions:

def cities_distance(city_lat, city_lon, user_lat, user_lon):
    """    
    :param city_lat: the value in the dataset's lat column to the corresponding city
    :param city_lon: the value in the dataset's lon column to the corresponding city
    :param user_lat: The corresponding lat value in the location dataset of the city selected by the user
    :param user_lon: The corresponding lon value in the location dataset of the city selected by the user
    
    :return: The value in kilometers of the distance between the two cities.
    
    Usage of the Vicenty distance
    """
    
    from geopy.distance import vincenty
    
    column_city = (city_lat, city_lon)
    user_city = (user_lat, user_lon)
    
    return (vincenty(column_city, user_city).km)

def distance_abs_value(a_value, b_value):
    return abs(a_value - b_value)

def w_s(city_row, brand_row, type_row, year_row):
    import numpy as np
    weigth = 100
    brand_weight = 40
    type_weight = 40
    year_weight = 10
    city_weight = 10
    
    params = np.array([city_row, brand_row, type_row, year_row])
    weights = np.array([city_weight, brand_weight, type_weight, year_weight])
    
    num = sum(params * weights) * 1.0
    return num/weigth

# %%
#Example of request of a user
user_request = ('madrid', 'bmw', 'custom', 2000)

# We need to calculate some variables:
user_lat = float(df_locations[df_locations['city'] == user_request[0]].lat)
user_lon = float(df_locations[df_locations['city'] == user_request[0]].lon)
user_brand = int(df_rank_moto_brand[df_rank_moto_brand['brand'] == user_request[1]].brand_score)
user_type = int(df_rank_moto_type[df_rank_moto_type['type'] == user_request[2]].type_score)
user_year = user_request[3]

user_vars = [user_brand, user_type, user_year]
score_columns = ['brand_score', 'type_score', 'year']

# %%
df_motos_raw_coord_brand_types['city_metric'] = df_motos_raw_coord_brand_types.apply(lambda row: cities_distance(row['lat'], row['lon'], user_lat, user_lon), axis=1)

for i, element in enumerate(['brand', 'type', 'year']):
    new_column = element + '_metric'
    print new_column, score_columns[i], user_vars[i]
    df_motos_raw_coord_brand_types[new_column] = df_motos_raw_coord_brand_types.apply(lambda row: distance_abs_value(int(row[score_columns[i]]), user_vars[i]), axis=1)
    
#!!! Revisar ranking de motos, falta alguna, por eso aparenden NAN en la columna brand_score al hacer el merge

df_motos_raw_coord_brand_types['total_metric_pond'] = df_motos_raw_coord_brand_types.apply(lambda row: w_s(row['city_metric'], row['brand_metric'], row['type_metric'], row['year_metric']), axis = 1)
# Out:
# brand_metric brand_score 356
# type_metric type_score 280
# year_metric year 2000

# %%
results = df_motos_raw_coord_brand_types.sort_values(by = ['total_metric_pond'], ascending=True)

# %%
results.head(10)
# Out:
#         city brand             model    type      cc                  color  \
# 4920  madrid   bmw  r_1200_c_classic  custom  1170.0                  cobre
# 3496  madrid   bmw         r_1200_cl  custom  1170.0                   gris
# 2538  madrid   bmw  r_1200_c_montauk  custom  1200.0                  negro
# 2363  madrid   bmw          r_1200_c  custom  1170.0                  negro
# 567   madrid   bmw  r_1200_c_montauk  custom  1200.0          not specified
# 5162  madrid   bmw           r_850_r   naked   848.0          not specified
# 3739  madrid   bmw          r_1150_r   naked  1130.0          not specified
# 4941  madrid   bmw           r_850_r   naked   848.0             negra-gris
# 3861  madrid   bmw           r_850_r   naked   848.0                burdeos
# 1175  madrid   bmw           r_850_r   naked   848.0  gris plomo metalizado
#
#             km  year price                                                url  \
# 4920   33000.0  2000  9800  http://motos.net/ocasion/bmw/r_1200_c_classic/...
# 3496  127700.0  2004  6500  http://motos.net/ocasion/bmw/r_1200_cl/2004-en...
# 2538   31000.0  2004  8890  http://motos.net/ocasion/bmw/r_1200_c_montauk/...
# 2363   16000.0  2004  9500  http://motos.net/ocasion/bmw/r_1200_c/2004-en-...
# 567   148000.0  2004  7300  http://motos.net/ocasion/bmw/r_1200_c_montauk/...
# 5162   45100.0  2000  2600  http://motos.net/ocasion/bmw/r_850_r/2000-en-m...
# 3739  115000.0  2001  4300  http://motos.net/ocasion/bmw/r_1150_r/2001-en-...
# 4941  135000.0  1998  3900  http://motos.net/ocasion/bmw/r_850_r/1998-en-m...
# 3861  118000.0  1998  2900  http://motos.net/ocasion/bmw/r_850_r/1998-en-m...
# 1175   80000.0  1997  3900  http://motos.net/ocasion/bmw/r_850_r/1997-en-m...
#
#             lat       lon  brand_score  type_score  city_metric  brand_metric  \
# 4920  40.416705 -3.703582        356.0         280          0.0             0
# 3496  40.416705 -3.703582        356.0         280          0.0             0
# 2538  40.416705 -3.703582        356.0         280          0.0             0
# 2363  40.416705 -3.703582        356.0         280          0.0             0
# 567   40.416705 -3.703582        356.0         280          0.0             0
# 5162  40.416705 -3.703582        356.0         260          0.0             0
# 3739  40.416705 -3.703582        356.0         260          0.0             0
# 4941  40.416705 -3.703582        356.0         260          0.0             0
# 3861  40.416705 -3.703582        356.0         260          0.0             0
# 1175  40.416705 -3.703582        356.0         260          0.0             0
#
#       type_metric  year_metric  total_metric_pond
# 4920            0            0                0.0
# 3496            0            4                0.4
# 2538            0            4                0.4
# 2363            0            4                0.4
# 567             0            4                0.4
# 5162           20            0                8.0
# 3739           20            1                8.1
# 4941           20            2                8.2
# 3861           20            2                8.2
# 1175           20            3                8.3

# %%
df_motos_raw_coord_brand_types.type.unique()
# Out:
# array(['trail', 'naked', 'scooters_+125cc', 'custom', 'sport', 'cross',
#        'scooter_125cc', 'turismo', 'enduro', 'scooters_50cc',
#        'supermotard', 'trial', 'ciclomotor', 'con_marchas', 'infantil'], dtype=object)

# %%
df_motos_raw_coord_brand_types[df_motos_raw_coord_brand_types.type=='con_marchas']

# %%
import pandas as pd
test = pd.read_csv('df_motos_raw_coord_brand_type.csv', sep=',', encoding = 'utf-8')

# %%
if df_rank_moto_brand[df_rank_moto_brand['brand'] == 'periquito'].brand_score.empty:
    print "none"
# Out:
# none

# %%
user_brand
# Out:
# 19

# %%
brand_in_df_list = [(brand, 'N/A') for brand in sorted(df_motos_raw_coord_brand_types.brand.unique())]

# %%
df_brand_in_df_list = pd.DataFrame.from_records(brand_in_df_list, columns = ['brand', 'brand_score'])

# %%
df_brand_in_df_list.head(5)
# Out:
#             brand  brand_score
# 0            adly            0
# 1            aeon            0
# 2          aiyumo            0
# 3             ajp            0
# 4  alpina renania            0

# %%
df_rank_moto_brand.head()
# Out:
#              brand  brand_score
# 0           yamaha          646
# 1            honda          635
# 2           suzuki          580
# 3           ducati          473
# 4  harley davidson          434

# %%
df_rank_final = pd.merge(df_brand_in_df_list, df_rank_moto_brand, on = 'brand', how = 'left')

# %%
df_rank_final.head(5)
# Out:
#             brand  brand_score_x  brand_score_y
# 0            adly              0           19.0
# 1            aeon              0            NaN
# 2          aiyumo              0           10.0
# 3             ajp              0            NaN
# 4  alpina renania              0            NaN

# %%
rank_values = df_rank_moto_brand.values.tolist()
brands_rank_values =  df_rank_moto_brand.brand.values
for df_brand in brand_in_df_list:
    if df_brand[0] not in brands_rank_values:
        rank_values.append([df_brand[0],0])

# %%
rank_values
# Out:
# [['yamaha', 646L],
#  ['honda', 635L],
#  ['suzuki', 580L],
#  ['ducati', 473L],
#  ['harley davidson', 434L],
#  ['kawasaki', 378L],
#  ['bmw', 356L],
#  ['ktm', 332L],
#  ['aprilia', 205L],
#  ['vespa', 144L],
#  ['derbi', 120L],
#  ['triumph', 120L],
#  ['bultaco', 94L],
#  ['gas-gas', 72L],
#  ['gas gas', 72L],
#  ['hyosung', 58L],
#  ['sym', 46L],
#  ['gilera', 42L],
#  ['motor-hispania', 40L],
#  ['husqvarna', 40L],
#  ['hammel', 37L],
#  ['kymco', 37L],
#  ['mv-agusta', 36L],
#  ['moto guzzi', 33L],
#  ['buell', 30L],
#  ['rieju', 26L],
#  ['beta', 24L],
#  ['benelli', 21L],
#  ['daelim', 20L],
#  ['keeway', 20L],
#  ['sherco', 20L],
#  ['jincheng', 20L],
#  ['dh-haotian', 20L],
#  ['alfer', 19L],
#  ['bimota', 19L],
#  ['adly', 19L],
#  ['adly-moto', 19L],
#  ['bombardier', 18L],
#  ['piaggio', 16L],
#  ['polini', 15L],
#  ['linhai', 10L],
#  ['meko', 10L],
#  ['azel', 10L],
#  ['muz', 10L],
#  ['mbk', 10L],
#  ['kenrod', 10L],
#  ['macbor', 10L],
#  ['sumco', 10L],
#  ['clipic', 10L],
#  ['aiyumo', 10L],
#  ['generic', 10L],
#  ['i-moto', 10L],
#  ['huatian', 10L],
#  ['goes', 10L],
#  ['blata', 8L],
#  ['malaguti', 8L],
#  ['voxan', 8L],
#  ['vor', 8L],
#  ['victory', 8L],
#  ['tgb', 8L],
#  ['scorpa', 8L],
#  ['sachs', 8L],
#  ['moto tm', 8L],
#  ['cagiva', 8L],
#  ['csr', 8L],
#  ['leonart', 8L],
#  ['italjet', 8L],
#  ['polaris', 8L],
#  ['cpi', 8L],
#  ['husaberg', 8L],
#  ['emc-puch', 8L],
#  ['peugeot', 3L],
#  ['aeon', 0],
#  ['ajp', 0],
#  ['alpina renania', 0],
#  ['american ironhorse', 0],
#  ['apollo orion', 0],
#  ['arctic cat', 0],
#  ['big dog', 0],
#  ['brammo', 0],
#  ['brp', 0],
#  ['btm', 0],
#  ['can-am', 0],
#  ['cfmoto', 0],
#  ['chopper nation', 0],
#  ['cooltra', 0],
#  ['dak', 0],
#  ['dh haotian', 0],
#  ['dorton', 0],
#  ['e-max', 0],
#  ['elmoto', 0],
#  ['fantic', 0],
#  ['fb mondial', 0],
#  ['govecs', 0],
#  ['gowinn', 0],
#  ['hanway', 0],
#  ['hm', 0],
#  ['hsun', 0],
#  ['hudson boss', 0],
#  ['imr', 0],
#  ['indian', 0],
#  ['innocenti', 0],
#  ['jianshe', 0],
#  ['jin lun', 0],
#  ['jonway', 0],
#  ['kangxin', 0],
#  ['kinroad', 0],
#  ['ksr moto', 0],
#  ['lambretta', 0],
#  ['lanvertti', 0],
#  ['lectric', 0],
#  ['lem', 0],
#  ['lemev', 0],
#  ['lifan', 0],
#  ['lml', 0],
#  ['mash', 0],
#  ['mecatecno', 0],
#  ['megelli', 0],
#  ['mobilette', 0],
#  ['monkey bike', 0],
#  ['montesa', 0],
#  ['moto morini', 0],
#  ['motogac', 0],
#  ['motor hispania', 0],
#  ['mtm', 0],
#  ['mtr', 0],
#  ['mv agusta', 0],
#  ['mxonda', 0],
#  ['orcal', 0],
#  ['orion', 0],
#  ['oset', 0],
#  ['ossa', 0],
#  ['puch', 0],
#  ['qingqi', 0],
#  ['quadro', 0],
#  ['rav', 0],
#  ['rebel', 0],
#  ['renault', 0],
#  ['ridley motorcycles', 0],
#  ['riya', 0],
#  ['roan', 0],
#  ['royal enfield', 0],
#  ['samada', 0],
#  ['scomadi', 0],
#  ['sumo', 0],
#  ['tbq', 0],
#  ['tm', 0],
#  ['torrot', 0],
#  ['ural', 0],
#  ['vertigo', 0],
#  ['vespino', 0],
#  ['via scooter', 0],
#  ['vmoto', 0],
#  ['wildlander', 0],
#  ['wottan', 0],
#  ['xingyue', 0],
#  ['xmotos', 0],
#  ['ycf', 0],
#  ['young rider', 0],
#  ['zero', 0],
#  ['zero motorcycles', 0],
#  ['zms motors', 0],
#  ['znen', 0],
#  ['zongshen', 0]]
