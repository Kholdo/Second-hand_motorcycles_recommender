# %%
from recommender_class import Recommender

# %%
r = Recommender('barcelona', 'bmw', 'custom', 2000, 30)

# %%
r.recommender()
# Out:
#             city brand                 model    type                color  \
# 8293   barcelona   bmw      r_1200_c_classic  custom                 azul
# 10658  barcelona   bmw      r_1200_c_classic  custom                beige
# 10764  barcelona   bmw              r_1200_c  custom        not specified
# 11325  barcelona   bmw  r_1200_c_independent  custom  beige y azul marino
# 8232   barcelona   bmw      r_1200_c_montauk  custom                negro
# 11946  barcelona   bmw              r_1100_r   naked        not specified
# 10873  barcelona   bmw               r_850_r   naked                negre
# 11016  barcelona   bmw              r_1100_r   naked         gris grafito
# 10763  barcelona   bmw              r_1150_r   naked              granate
# 8879   barcelona   bmw              r_1150_r   naked        not specified
# 10720  barcelona   bmw               r_850_r   naked                plata
# 9608   barcelona   bmw              r_1100_r   naked              granate
# 11149  barcelona   bmw              r_1100_r   naked                verde
# 11370  barcelona   bmw               r_850_r   naked                plata
# 7854   barcelona   bmw              r_1150_r   naked                 rojo
# 9792   barcelona   bmw               r_850_r   naked                 gris
# 10753  barcelona   bmw              r_1100_r   naked                verde
# 8114   barcelona   bmw               r_850_r   naked                 azul
# 9024   barcelona   bmw              r_1150_r   naked                negro
# 8101   barcelona   bmw              r_1150_r   naked                negro
# 8029   barcelona   bmw               r_850_r   naked                plata
# 10697  barcelona   bmw              r_1150_r   naked                 azul
# 9397   barcelona   bmw               r_850_r   naked                 gris
# 11694  barcelona   bmw               r_850_r   naked        not specified
# 11489  barcelona   bmw               r_850_r   naked           gris plata
# 8371   barcelona   bmw              r_1150_r   naked                negro
# 11671  barcelona   bmw               r_850_r   naked                plata
# 11121  barcelona   bmw              r_1150_r   naked      gris metalizado
# 9095   barcelona   bmw               r_850_r   naked                plata
# 10862  barcelona   bmw              k_1200_r   naked                negra
#
#              km  year  price  \
# 8293    27000.0  2000   7500
# 10658  114000.0  1999   8790
# 10764   56000.0  1998   7850
# 11325   49000.0  2004   8000
# 8232    21000.0  2004  10500
# 11946  124000.0  2000   2750
# 10873  111000.0  2000   2500
# 11016   81000.0  1999   3000
# 10763   62000.0  2002   4500
# 8879    80904.0  2002   4500
# 10720   79080.0  1998   2850
# 9608   125000.0  1998   3000
# 11149  103000.0  1998   3000
# 11370   90000.0  2002   3100
# 7854    32879.0  2003   5190
# 9792    72000.0  2003   5000
# 10753   59000.0  1997   3300
# 8114    45000.0  1997   3500
# 9024    29900.0  2003   4900
# 8101    46500.0  2003   4250
# 8029    81200.0  2003   4800
# 10697  107000.0  2003   3800
# 9397    79000.0  2004   4250
# 11694  145000.0  2004   3000
# 11489   89000.0  2004   4500
# 8371    54000.0  2004   4900
# 11671   66000.0  2005   4000
# 11121  125000.0  2005   3300
# 9095    66000.0  2005   4250
# 10862   35000.0  2005   6000
#
#                                                      url  total_metric_pond
# 8293   http://motos.net/ocasion/bmw/r_1200_c_classic/...                0.0
# 10658  http://motos.net/ocasion/bmw/r_1200_c_classic/...                0.1
# 10764  http://motos.net/ocasion/bmw/r_1200_c/1998-en-...                0.2
# 11325  http://motos.net/ocasion/bmw/r_1200_c_independ...                0.4
# 8232   http://motos.net/ocasion/bmw/r_1200_c_montauk/...                0.4
# 11946  http://motos.net/ocasion/bmw/r_1100_r/2000-en-...                8.0
# 10873  http://motos.net/ocasion/bmw/r_850_r/2000-en-b...                8.0
# 11016  http://motos.net/ocasion/bmw/r_1100_r/1999-en-...                8.1
# 10763  http://motos.net/ocasion/bmw/r_1150_r/2002-en-...                8.2
# 8879   http://motos.net/ocasion/bmw/r_1150_r/2002-en-...                8.2
# 10720  http://motos.net/ocasion/bmw/r_850_r/1998-en-b...                8.2
# 9608   http://motos.net/ocasion/bmw/r_1100_r/1998-en-...                8.2
# 11149  http://motos.net/ocasion/bmw/r_1100_r/1998-en-...                8.2
# 11370  http://motos.net/ocasion/bmw/r_850_r/2002-en-b...                8.2
# 7854   http://motos.net/ocasion/bmw/r_1150_r/2003-en-...                8.3
# 9792   http://motos.net/ocasion/bmw/r_850_r/2003-en-b...                8.3
# 10753  http://motos.net/ocasion/bmw/r_1100_r/1997-en-...                8.3
# 8114   http://motos.net/ocasion/bmw/r_850_r/1997-en-b...                8.3
# 9024   http://motos.net/ocasion/bmw/r_1150_r/2003-en-...                8.3
# 8101   http://motos.net/ocasion/bmw/r_1150_r/2003-en-...                8.3
# 8029   http://motos.net/ocasion/bmw/r_850_r/2003-en-b...                8.3
# 10697  http://motos.net/ocasion/bmw/r_1150_r/2003-en-...                8.3
# 9397   http://motos.net/ocasion/bmw/r_850_r/2004-en-b...                8.4
# 11694  http://motos.net/ocasion/bmw/r_850_r/2004-en-b...                8.4
# 11489  http://motos.net/ocasion/bmw/r_850_r/2004-en-b...                8.4
# 8371   http://motos.net/ocasion/bmw/r_1150_r/2004-en-...                8.4
# 11671  http://motos.net/ocasion/bmw/r_850_r/2005-en-b...                8.5
# 11121  http://motos.net/ocasion/bmw/r_1150_r/2005-en-...                8.5
# 9095   http://motos.net/ocasion/bmw/r_850_r/2005-en-b...                8.5
# 10862  http://motos.net/ocasion/bmw/k_1200_r/2005-en-...                8.5

# %%
r.recommender().values.tolist()
# Out:
# [[u'barcelona',
#   u'bmw',
#   u'r_1200_c_classic',
#   u'custom',
#   u'azul',
#   27000.0,
#   2000L,
#   7500L,
#   u'http://motos.net/ocasion/bmw/r_1200_c_classic/2000-en-barcelona-6451614.htm',
#   0.0],
#  [u'barcelona',
#   u'bmw',
#   u'r_1200_c_classic',
#   u'custom',
#   u'beige',
#   114000.0,
#   1999L,
#   8790L,
#   u'http://motos.net/ocasion/bmw/r_1200_c_classic/1999-en-barcelona-6399376.htm',
#   0.1],
#  [u'barcelona',
#   u'bmw',
#   u'r_1200_c',
#   u'custom',
#   u'not specified',
#   56000.0,
#   1998L,
#   7850L,
#   u'http://motos.net/ocasion/bmw/r_1200_c/1998-en-barcelona-6395729.htm',
#   0.2],
#  [u'barcelona',
#   u'bmw',
#   u'r_1200_c_independent',
#   u'custom',
#   u'beige y azul marino',
#   49000.0,
#   2004L,
#   8000L,
#   u'http://motos.net/ocasion/bmw/r_1200_c_independent/2004-en-barcelona-6369401.htm',
#   0.4],
#  [u'barcelona',
#   u'bmw',
#   u'r_1200_c_montauk',
#   u'custom',
#   u'negro',
#   21000.0,
#   2004L,
#   10500L,
#   u'http://motos.net/ocasion/bmw/r_1200_c_montauk/2004-en-barcelona-6452494.htm',
#   0.4],
#  [u'barcelona',
#   u'bmw',
#   u'r_1100_r',
#   u'naked',
#   u'not specified',
#   124000.0,
#   2000L,
#   2750L,
#   u'http://motos.net/ocasion/bmw/r_1100_r/2000-en-barcelona-6377335.htm',
#   8.0],
#  [u'barcelona',
#   u'bmw',
#   u'r_850_r',
#   u'naked',
#   u'negre',
#   111000.0,
#   2000L,
#   2500L,
#   u'http://motos.net/ocasion/bmw/r_850_r/2000-en-barcelona-6391489.htm',
#   8.0],
#  [u'barcelona',
#   u'bmw',
#   u'r_1100_r',
#   u'naked',
#   u'gris grafito',
#   81000.0,
#   1999L,
#   3000L,
#   u'http://motos.net/ocasion/bmw/r_1100_r/1999-en-barcelona-6386325.htm',
#   8.1],
#  [u'barcelona',
#   u'bmw',
#   u'r_1150_r',
#   u'naked',
#   u'granate',
#   62000.0,
#   2002L,
#   4500L,
#   u'http://motos.net/ocasion/bmw/r_1150_r/2002-en-barcelona-6395730.htm',
#   8.2],
#  [u'barcelona',
#   u'bmw',
#   u'r_1150_r',
#   u'naked',
#   u'not specified',
#   80904.0,
#   2002L,
#   4500L,
#   u'http://motos.net/ocasion/bmw/r_1150_r/2002-en-barcelona-6436092.htm',
#   8.2],
#  [u'barcelona',
#   u'bmw',
#   u'r_850_r',
#   u'naked',
#   u'plata',
#   79080.0,
#   1998L,
#   2850L,
#   u'http://motos.net/ocasion/bmw/r_850_r/1998-en-barcelona-6397385.htm',
#   8.2],
#  [u'barcelona',
#   u'bmw',
#   u'r_1100_r',
#   u'naked',
#   u'granate',
#   125000.0,
#   1998L,
#   3000L,
#   u'http://motos.net/ocasion/bmw/r_1100_r/1998-en-barcelona-6428256.htm',
#   8.2],
#  [u'barcelona',
#   u'bmw',
#   u'r_1100_r',
#   u'naked',
#   u'verde',
#   103000.0,
#   1998L,
#   3000L,
#   u'http://motos.net/ocasion/bmw/r_1100_r/1998-en-barcelona-6380395.htm',
#   8.2],
#  [u'barcelona',
#   u'bmw',
#   u'r_850_r',
#   u'naked',
#   u'plata',
#   90000.0,
#   2002L,
#   3100L,
#   u'http://motos.net/ocasion/bmw/r_850_r/2002-en-barcelona-6353897.htm',
#   8.2],
#  [u'barcelona',
#   u'bmw',
#   u'r_1150_r',
#   u'naked',
#   u'rojo',
#   32879.0,
#   2003L,
#   5190L,
#   u'http://motos.net/ocasion/bmw/r_1150_r/2003-en-barcelona-6438911.htm',
#   8.3],
#  [u'barcelona',
#   u'bmw',
#   u'r_850_r',
#   u'naked',
#   u'gris',
#   72000.0,
#   2003L,
#   5000L,
#   u'http://motos.net/ocasion/bmw/r_850_r/2003-en-barcelona-6423950.htm',
#   8.3],
#  [u'barcelona',
#   u'bmw',
#   u'r_1100_r',
#   u'naked',
#   u'verde',
#   59000.0,
#   1997L,
#   3300L,
#   u'http://motos.net/ocasion/bmw/r_1100_r/1997-en-barcelona-6396279.htm',
#   8.3],
#  [u'barcelona',
#   u'bmw',
#   u'r_850_r',
#   u'naked',
#   u'azul',
#   45000.0,
#   1997L,
#   3500L,
#   u'http://motos.net/ocasion/bmw/r_850_r/1997-en-barcelona-6298994.htm',
#   8.3],
#  [u'barcelona',
#   u'bmw',
#   u'r_1150_r',
#   u'naked',
#   u'negro',
#   29900.0,
#   2003L,
#   4900L,
#   u'http://motos.net/ocasion/bmw/r_1150_r/2003-en-barcelona-6421142.htm',
#   8.3],
#  [u'barcelona',
#   u'bmw',
#   u'r_1150_r',
#   u'naked',
#   u'negro',
#   46500.0,
#   2003L,
#   4250L,
#   u'http://motos.net/ocasion/bmw/r_1150_r/2003-en-barcelona-6453893.htm',
#   8.3],
#  [u'barcelona',
#   u'bmw',
#   u'r_850_r',
#   u'naked',
#   u'plata',
#   81200.0,
#   2003L,
#   4800L,
#   u'http://motos.net/ocasion/bmw/r_850_r/2003-en-barcelona-6443905.htm',
#   8.3],
#  [u'barcelona',
#   u'bmw',
#   u'r_1150_r',
#   u'naked',
#   u'azul',
#   107000.0,
#   2003L,
#   3800L,
#   u'http://motos.net/ocasion/bmw/r_1150_r/2003-en-barcelona-6398301.htm',
#   8.3],
#  [u'barcelona',
#   u'bmw',
#   u'r_850_r',
#   u'naked',
#   u'gris',
#   79000.0,
#   2004L,
#   4250L,
#   u'http://motos.net/ocasion/bmw/r_850_r/2004-en-barcelona-6433243.htm',
#   8.4],
#  [u'barcelona',
#   u'bmw',
#   u'r_850_r',
#   u'naked',
#   u'not specified',
#   145000.0,
#   2004L,
#   3000L,
#   u'http://motos.net/ocasion/bmw/r_850_r/2004-en-barcelona-6428906.htm',
#   8.4],
#  [u'barcelona',
#   u'bmw',
#   u'r_850_r',
#   u'naked',
#   u'gris plata',
#   89000.0,
#   2004L,
#   4500L,
#   u'http://motos.net/ocasion/bmw/r_850_r/2004-en-barcelona-6465738.htm',
#   8.4],
#  [u'barcelona',
#   u'bmw',
#   u'r_1150_r',
#   u'naked',
#   u'negro',
#   54000.0,
#   2004L,
#   4900L,
#   u'http://motos.net/ocasion/bmw/r_1150_r/2004-en-barcelona-6450313.htm',
#   8.4],
#  [u'barcelona',
#   u'bmw',
#   u'r_850_r',
#   u'naked',
#   u'plata',
#   66000.0,
#   2005L,
#   4000L,
#   u'http://motos.net/ocasion/bmw/r_850_r/2005-en-barcelona-6433815.htm',
#   8.5],
#  [u'barcelona',
#   u'bmw',
#   u'r_1150_r',
#   u'naked',
#   u'gris metalizado',
#   125000.0,
#   2005L,
#   3300L,
#   u'http://motos.net/ocasion/bmw/r_1150_r/2005-en-barcelona-6381676.htm',
#   8.5],
#  [u'barcelona',
#   u'bmw',
#   u'r_850_r',
#   u'naked',
#   u'plata',
#   66000.0,
#   2005L,
#   4250L,
#   u'http://motos.net/ocasion/bmw/r_850_r/2005-en-barcelona-6439521.htm',
#   8.5],
#  [u'barcelona',
#   u'bmw',
#   u'k_1200_r',
#   u'naked',
#   u'negra',
#   35000.0,
#   2005L,
#   6000L,
#   u'http://motos.net/ocasion/bmw/k_1200_r/2005-en-barcelona-6392049.htm',
#   8.5]]

# %%
import pandas as pd
df_motos_raw = pd.read_csv('scraped_data/motos_raw_data.csv', sep=';')
df_motos_raw.shape
# Out:
# (26511, 10)

# %%
df_motos_raw['color'].fillna('not specified', inplace=True)

# %%
df_motos_raw.shape
# Out:
# (26511, 10)

# %% [markdown]
# Data cleaning

# %%
# Convert the dataframe to lower case
df_motos_raw = df_motos_raw.apply(lambda x: x.astype(str).str.lower())

# %%
#Join the words in the 'model' and 'type' fields with an underscore
df_motos_raw['model'] = df_motos_raw['model'].str.replace(' ', '_')
df_motos_raw['type'] = df_motos_raw['type'].str.replace(' ', '_')

# %%
# Looking for duplicates
df_motos_raw['is_duplicated'] = df_motos_raw.duplicated()
duplicates = df_motos_raw['is_duplicated'].sum()
print '%d duplicates' %duplicates
# Out:
# 93 duplicates

# %%
# Removing duplicates and delete 'is_duplicated' column
df_motos_raw = df_motos_raw.loc[df_motos_raw['is_duplicated']==False]
df_motos_raw = df_motos_raw.drop('is_duplicated', 1)
df_motos_raw.shape
# Out:
# (26418, 10)

# %%
# Lets investigate column by column the NaNs we have in the dataframe
for column in df_motos_raw.columns:
    n_nan = df_motos_raw[column]=='nan'
    print column + " %d -- > %f" %(n_nan.sum(), (n_nan.sum()*1.0)/df_motos_raw.shape[0]*100)
# Out:
# city 0 -- > 0.000000
# brand 0 -- > 0.000000
# model 0 -- > 0.000000
# type 0 -- > 0.000000
# cc 95 -- > 0.359603
# color 0 -- > 0.000000
# km 1631 -- > 6.173821
# year 0 -- > 0.000000
# price 0 -- > 0.000000
# url 0 -- > 0.000000

# %%
# Lets investigate the unique values we have in the columns
for column in ['city', 'brand', 'model', 'type', 'color', 'year']:
    column_uv = df_motos_raw[column].unique()
    print column + " --> " + "%d unique values" %len(sorted(column_uv))
# Out:
# city --> 52 unique values
# brand --> 148 unique values
# model --> 3011 unique values
# type --> 15 unique values
# color --> 1923 unique values
# year --> 48 unique values

# %% [markdown]
# Merge some data

# %%
#In order to calculate our first metric, we will use the following columns:
# "lon" and "lat" : These are the longitude and latitude of the corresponding city. We will add them later.
# "brand", "model", "type", "year"

# %%
# Calculating the longitude and latitude of the cities
import geopy
from geopy.geocoders import Nominatim
geolocator = Nominatim()

# %%
cities = df_motos_raw['city'].unique()
locations_rows = []
for city in cities:
    location = geolocator.geocode([city], timeout = 15)
    locations_rows.append([city, location.latitude, location.longitude])
#Save into a csv
df_locations = pd.DataFrame(locations_rows, columns = ['city', 'lat', 'lon'])
#df_locations.to_csv('auxiliary_data/locations_coords.csv', index = False)

# %%
df_locations.head(3)
# Out:
#       city        lat       lon
# 0   madrid  40.416705 -3.703582
# 1  navarra  42.612549 -1.830791
# 2  granada  37.183020 -3.602192

# %%
# Merge df_locations with df_motos_raw
df_motos_raw_coord = pd.merge(df_motos_raw, df_locations, on = 'city')
#Save into a csv
#df_motos_raw_coord.to_csv('df_motos_raw_coord.csv', index = False)

# %%
# We have created two csv files with a rank for the motos brands and types
# called rank_motos_brands.csv and rank_motos_types.csv

# With the first one, rank_motos_brands.csv, we are gint to create another  column, with a score to the corresponding brand
df_rank_moto_brand = pd.read_csv('scraped_data/rank_moto_brands.csv', sep=';')
df_motos_raw_coord_brand = pd.merge(df_motos_raw_coord, df_rank_moto_brand, on = 'brand', how = 'left')
#If the brand does not exist, the rank value will be zero
#!!OJO, AÑADIR MARCAS DE MOTOS QUE FALTAN ANTES DE PONER UN CERO!!!!!!!!!!!!!!!!!
df_motos_raw_coord_brand.brand_score.fillna(0, inplace=True)
# Save into a csv
df_motos_raw_coord_brand.to_csv('df_motos_coord_brand.csv', index = False)

# With the second one, rank_moto_types.csv, we are going to create another column, with a score to the corresponding type
df_rank_moto_type = pd.read_csv('auxiliary_data/rank_moto_types.csv', sep=';')
df_motos_raw_coord_brand_types = pd.merge(df_motos_raw_coord_brand, df_rank_moto_type, on = 'type', how = 'left')
#Save into a csv
df_motos_raw_coord_brand_types.to_csv('df_motos_raw_coord_brand_type.csv', index = False)

# %%
df_motos_raw_coord_brand_types.head(3)
# Out:
#      city   brand                model             type      cc   color  \
# 0  madrid     bmw            r_1200_gs            trail  1170.0    rojo
# 1  madrid  ducati         monster_696+            naked   696.0  blanco
# 2  madrid   kymco  super_dink_300i_abs  scooters_+125cc   299.0  blanco
#
#         km  year price                                                url  \
# 0  57400.0  2004  7490  http://motos.net/ocasion/bmw/r_1200_gs/2004-en...
# 1  18166.0  2011  5999  http://motos.net/ocasion/ducati/monster_696/20...
# 2   9644.0  2011  3299  http://motos.net/ocasion/kymco/super_dink_300i...
#
#          lat       lon  brand_score  type_score
# 0  40.416705 -3.703582        356.0         230
# 1  40.416705 -3.703582        473.0         260
# 2  40.416705 -3.703582         37.0         120

# %%
df_motos_raw_coord_brand_types[df_motos_raw_coord_brand_types.brand_score==0].brand.unique()
# Out:
# array(['dorton', 'mv agusta', 'quadro', 'indian', 'hanway', 'lml',
#        'jonway', 'qingqi', 'royal enfield', 'riya', 'monkey bike', 'znen',
#        'motor hispania', 'fantic', 'fb mondial', 'imr', 'hudson boss',
#        'rav', 'jin lun', 'oset', 'orcal', 'big dog', 'brp', 'montesa',
#        'ural', 'kinroad', 'mtr', 'zero', 'mash', 'mxonda', 'ksr moto',
#        'puch', 'jianshe', 'innocenti', 'arctic cat', 'zongshen',
#        'ridley motorcycles', 'american ironhorse', 'young rider', 'orion',
#        'mobilette', 'tm', 'torrot', 'vespino', 'moto morini',
#        'apollo orion', 'rebel', 'megelli', 'cooltra', 'lem', 'ossa',
#        'zero motorcycles', 'vertigo', 'govecs', 'can-am', 'kangxin',
#        'zms motors', 'hm', 'dh haotian', 'alpina renania', 'gowinn',
#        'xmotos', 'lambretta', 'brammo', 'scomadi', 'aeon', 'lifan', 'ycf',
#        'elmoto', 'renault', 'ajp', 'wildlander', 'sumo', 'mecatecno',
#        'wottan', 'lemev', 'e-max', 'samada', 'btm', 'vmoto', 'tbq', 'mtm',
#        'lanvertti', 'roan', 'chopper nation', 'motogac', 'adly',
#        'via scooter', 'hsun', 'dak', 'xingyue', 'cfmoto', 'lectric'], dtype=object)

# %%
# OK!, so we have a first version of the data we will use to recommend vehicles
# df_motos_raw_coord_brand_types
# Lets try to calculate the metric only with some fields. We are going to add these distances:
# cities distance, brand_distance, type_distance, year_distance
# We need to create some functions:

def cities_distance(city_lat, city_lon, user_lat, user_lon):
    """    
    :param city_lat: the value in the dataset's lat column to the corresponding city
    :param city_lon: the value in the dataset's lon column to the corresponding city
    :param user_lat: The corresponding lat value in the location dataset of the city selected by the user
    :param user_lon: The corresponding lon value in the location dataset of the city selected by the user
    
    :return: The value in kilometers of the distance between the two cities.
    
    Usage of the Vicenty distance
    """
    
    from geopy.distance import vincenty
    
    column_city = (city_lat, city_lon)
    user_city = (user_lat, user_lon)
    
    return (vincenty(column_city, user_city).km)

def distance_abs_value(a_value, b_value):
    return abs(a_value - b_value)

def w_s(city_row, brand_row, type_row, year_row):
    import numpy as np
    weigth = 100
    brand_weight = 40
    type_weight = 40
    year_weight = 10
    city_weight = 10
    
    params = np.array([city_row, brand_row, type_row, year_row])
    weights = np.array([city_weight, brand_weight, type_weight, year_weight])
    
    num = sum(params * weights) * 1.0
    return num/weigth

# %%
#Example of request of a user
user_request = ('madrid', 'bmw', 'custom', 2000)

# We need to calculate some variables:
user_lat = float(df_locations[df_locations['city'] == user_request[0]].lat)
user_lon = float(df_locations[df_locations['city'] == user_request[0]].lon)
user_brand = int(df_rank_moto_brand[df_rank_moto_brand['brand'] == user_request[1]].brand_score)
user_type = int(df_rank_moto_type[df_rank_moto_type['type'] == user_request[2]].type_score)
user_year = user_request[3]

user_vars = [user_brand, user_type, user_year]
score_columns = ['brand_score', 'type_score', 'year']

# %%
df_motos_raw_coord_brand_types['city_metric'] = df_motos_raw_coord_brand_types.apply(lambda row: cities_distance(row['lat'], row['lon'], user_lat, user_lon), axis=1)

for i, element in enumerate(['brand', 'type', 'year']):
    new_column = element + '_metric'
    print new_column, score_columns[i], user_vars[i]
    df_motos_raw_coord_brand_types[new_column] = df_motos_raw_coord_brand_types.apply(lambda row: distance_abs_value(int(row[score_columns[i]]), user_vars[i]), axis=1)
    
#!!! Revisar ranking de motos, falta alguna, por eso aparenden NAN en la columna brand_score al hacer el merge

df_motos_raw_coord_brand_types['total_metric_pond'] = df_motos_raw_coord_brand_types.apply(lambda row: w_s(row['city_metric'], row['brand_metric'], row['type_metric'], row['year_metric']), axis = 1)
# Out:
# brand_metric brand_score 356
# type_metric type_score 280
# year_metric year 2000

# %%
results = df_motos_raw_coord_brand_types.sort_values(by = ['total_metric_pond'], ascending=True)

# %%
results.head(100)
# Out:
#         city     brand                    model    type      cc  \
# 4920  madrid       bmw         r_1200_c_classic  custom  1170.0
# 3496  madrid       bmw                r_1200_cl  custom  1170.0
# 2538  madrid       bmw         r_1200_c_montauk  custom  1200.0
# 2363  madrid       bmw                 r_1200_c  custom  1170.0
# 567   madrid       bmw         r_1200_c_montauk  custom  1200.0
# 5162  madrid       bmw                  r_850_r   naked   848.0
# 3739  madrid       bmw                 r_1150_r   naked  1130.0
# 4941  madrid       bmw                  r_850_r   naked   848.0
# 3861  madrid       bmw                  r_850_r   naked   848.0
# 1175  madrid       bmw                  r_850_r   naked   848.0
# 5098  madrid       bmw                 r_1150_r   naked  1130.0
# 1926  madrid       bmw                 r_1150_r   naked  1130.0
# 3665  madrid       bmw                 r_1150_r   naked  1130.0
# 2245  madrid       bmw                  r_850_r   naked   848.0
# 3193  madrid       bmw                  r_850_r   naked   848.0
# 4043  madrid       bmw                  r_850_r   naked   848.0
# 806   madrid       bmw                  r_850_r   naked   848.0
# 5052  madrid       bmw                 r_1150_r   naked  1130.0
# 3472  madrid       bmw                 k_1200_r   naked  1157.0
# 1401  madrid       bmw                  r_850_r   naked   848.0
# 4604  madrid       bmw                  r_850_r   naked   848.0
# 3546  madrid       bmw                  r_850_r   naked   848.0
# 4764  madrid       bmw                  f_800_s   naked   798.0
# 3635  madrid       bmw                  f_800_s   naked   798.0
# 3099  madrid       bmw                  r_850_r   naked   848.0
# 1581  madrid       bmw                 k_1200_r   naked  1157.0
# 623   madrid       bmw                  f_800_s   naked   798.0
# 3343  madrid       bmw                  f_800_s   naked   798.0
# 4977  madrid       bmw                  r_850_r   naked   848.0
# 3267  madrid       bmw                  f_800_s   naked   798.0
# ...      ...       ...                      ...     ...     ...
# 4942  madrid       bmw                  f_800_r   naked   800.0
# 4258  madrid       bmw                 r_1200_r   naked  1170.0
# 214   madrid       bmw                 r_1200_r   naked  1170.0
# 3994  madrid  kawasaki            vulcan_500_en  custom   500.0
# 4120  madrid       bmw                  f_800_r   naked   800.0
# 227   madrid       bmw                  f_800_r   naked   800.0
# 2914  madrid       bmw                  f_800_s   naked   798.0
# 546   madrid       bmw                 r_1200_r   naked  1170.0
# 3522  madrid  kawasaki     vn_vulcan_800_clasic  custom   805.0
# 2978  madrid       bmw                 k_1300_r   naked  1293.0
# 2879  madrid       bmw                 r_1200_r   naked  1170.0
# 280   madrid       bmw                 r_1200_r   naked  1170.0
# 1435  madrid  kawasaki     vn_vulcan_800_clasic  custom   805.0
# 1497  madrid       bmw                  f_800_r   naked   800.0
# 1448  madrid       bmw                  f_800_r   naked   800.0
# 1397  madrid  kawasaki     vn_vulcan_800_clasic  custom   805.0
# 4000  madrid       bmw                  f_800_r   naked   800.0
# 3421  madrid       bmw                 k_1300_r   naked  1293.0
# 4876  madrid       bmw                  f_800_r   naked   800.0
# 4329  madrid       bmw                 k_1300_r   naked  1293.0
# 4960  madrid  kawasaki               vulcan_800  custom   800.0
# 575   madrid       bmw                  f_800_r   naked   800.0
# 4846  madrid  kawasaki               vulcan_500  custom   500.0
# 2945  madrid       bmw                 r_1200_r   naked  1170.0
# 2846  madrid  kawasaki     vn_vulcan_800_clasic  custom   805.0
# 2230  madrid       bmw                  f_800_r   naked   800.0
# 390   madrid       bmw  r_1200_r_90_aniversario   naked  1170.0
# 1438  madrid       bmw                  r_ninet   naked  1170.0
# 3139  madrid       bmw                  f_800_r   naked   800.0
# 75    madrid  kawasaki           vn_900_classic  custom   903.0
#
#                                      color        km  year  price  \
# 4920                                 cobre   33000.0  2000   9800
# 3496                                  gris  127700.0  2004   6500
# 2538                                 negro   31000.0  2004   8890
# 2363                                 negro   16000.0  2004   9500
# 567                          not specified  148000.0  2004   7300
# 5162                         not specified   45100.0  2000   2600
# 3739                         not specified  115000.0  2001   4300
# 4941                            negra-gris  135000.0  1998   3900
# 3861                               burdeos  118000.0  1998   2900
# 1175                 gris plomo metalizado   80000.0  1997   3900
# 5098                                  azul   83000.0  2003   3000
# 1926                         not specified   83000.0  2003   3000
# 3665                          rojo burdeos   42000.0  2003   5700
# 2245                                 negro   50300.0  2003   4600
# 3193                       gris metalizada   42000.0  2004   4300
# 4043                                  rojo  105000.0  2004   3800
# 806                          not specified  114000.0  2004   3999
# 5052                              amarillo   73000.0  2005   4900
# 3472                                 negro   40000.0  2005   6000
# 1401                         gris y blanco   67000.0  2005   4300
# 4604                                  gris   22700.0  2006   5700
# 3546                          gris grafito   52000.0  2006   4800
# 4764                                  rojo   45000.0  2006   4800
# 3635                              amarilla   47000.0  2006   3600
# 3099                                  gris   36500.0  2006   4800
# 1581                              amarilla   37000.0  2006   5500
# 623                                   rojo   47510.0  2006   3999
# 3343                                  roja   20000.0  2006   4500
# 4977                                  gris   44000.0  2006   6000
# 3267                                  rojo   29000.0  2006   3600
# ...                                    ...       ...   ...    ...
# 4942                                  gris   35000.0  2010   5200
# 4258                         not specified   42000.0  2011   9300
# 214                                  negro  120560.0  2011   5990
# 3994                         not specified   85000.0  1997   2500
# 4120                         not specified   41850.0  2011   5300
# 227                                   gris   29000.0  2011   5490
# 2914                                  girs   24600.0  2011   5500
# 546                                  negro  120560.0  2011   5990
# 3522                         not specified   35000.0  1997   3800
# 2978                                blanco   18000.0  2011  10995
# 2879                         not specified   57500.0  2011   7700
# 280                          not specified   16000.0  2012   8800
# 1435                         not specified   13000.0  2004   4200
# 1497                         not specified   23332.0  2012   6300
# 1448                         not specified   49411.0  2012   5899
# 1397                                 negro   12000.0  2005   4900
# 4000                               naranja   36000.0  2013   5600
# 3421                            verde/gris   12000.0  2013  11700
# 4876                         rojo/aluminio   20000.0  2013   6000
# 4329                        gris antracita   11400.0  2013  12900
# 4960                                 negro    2500.0  1995   3500
# 575             blanco alpino y negro seda   49000.0  2013   5250
# 4846                                 negro   22000.0  1995   2200
# 2945                         gris tormenta   14000.0  2013  10800
# 2846                                 negro    7400.0  2006   4800
# 2230  azul racing metalizado/blanco alpino    5931.0  2014   7700
# 390                                  negra   11391.0  2014  12500
# 1438                         not specified    4000.0  2014  12800
# 3139                          blanco/negro   25220.0  2014   6500
# 75                           not specified   69564.0  2006   3990
#
#                                                     url        lat       lon  \
# 4920  http://motos.net/ocasion/bmw/r_1200_c_classic/...  40.416705 -3.703582
# 3496  http://motos.net/ocasion/bmw/r_1200_cl/2004-en...  40.416705 -3.703582
# 2538  http://motos.net/ocasion/bmw/r_1200_c_montauk/...  40.416705 -3.703582
# 2363  http://motos.net/ocasion/bmw/r_1200_c/2004-en-...  40.416705 -3.703582
# 567   http://motos.net/ocasion/bmw/r_1200_c_montauk/...  40.416705 -3.703582
# 5162  http://motos.net/ocasion/bmw/r_850_r/2000-en-m...  40.416705 -3.703582
# 3739  http://motos.net/ocasion/bmw/r_1150_r/2001-en-...  40.416705 -3.703582
# 4941  http://motos.net/ocasion/bmw/r_850_r/1998-en-m...  40.416705 -3.703582
# 3861  http://motos.net/ocasion/bmw/r_850_r/1998-en-m...  40.416705 -3.703582
# 1175  http://motos.net/ocasion/bmw/r_850_r/1997-en-m...  40.416705 -3.703582
# 5098  http://motos.net/ocasion/bmw/r_1150_r/2003-en-...  40.416705 -3.703582
# 1926  http://motos.net/ocasion/bmw/r_1150_r/2003-en-...  40.416705 -3.703582
# 3665  http://motos.net/ocasion/bmw/r_1150_r/2003-en-...  40.416705 -3.703582
# 2245  http://motos.net/ocasion/bmw/r_850_r/2003-en-m...  40.416705 -3.703582
# 3193  http://motos.net/ocasion/bmw/r_850_r/2004-en-m...  40.416705 -3.703582
# 4043  http://motos.net/ocasion/bmw/r_850_r/2004-en-m...  40.416705 -3.703582
# 806   http://motos.net/ocasion/bmw/r_850_r/2004-en-m...  40.416705 -3.703582
# 5052  http://motos.net/ocasion/bmw/r_1150_r/2005-en-...  40.416705 -3.703582
# 3472  http://motos.net/ocasion/bmw/k_1200_r/2005-en-...  40.416705 -3.703582
# 1401  http://motos.net/ocasion/bmw/r_850_r/2005-en-m...  40.416705 -3.703582
# 4604  http://motos.net/ocasion/bmw/r_850_r/2006-en-m...  40.416705 -3.703582
# 3546  http://motos.net/ocasion/bmw/r_850_r/2006-en-m...  40.416705 -3.703582
# 4764  http://motos.net/ocasion/bmw/f_800_s/2006-en-m...  40.416705 -3.703582
# 3635  http://motos.net/ocasion/bmw/f_800_s/2006-en-m...  40.416705 -3.703582
# 3099  http://motos.net/ocasion/bmw/r_850_r/2006-en-m...  40.416705 -3.703582
# 1581  http://motos.net/ocasion/bmw/k_1200_r/2006-en-...  40.416705 -3.703582
# 623   http://motos.net/ocasion/bmw/f_800_s/2006-en-m...  40.416705 -3.703582
# 3343  http://motos.net/ocasion/bmw/f_800_s/2006-en-m...  40.416705 -3.703582
# 4977  http://motos.net/ocasion/bmw/r_850_r/2006-en-m...  40.416705 -3.703582
# 3267  http://motos.net/ocasion/bmw/f_800_s/2006-en-m...  40.416705 -3.703582
# ...                                                 ...        ...       ...
# 4942  http://motos.net/ocasion/bmw/f_800_r/2010-en-m...  40.416705 -3.703582
# 4258  http://motos.net/ocasion/bmw/r_1200_r/2011-en-...  40.416705 -3.703582
# 214   http://motos.net/ocasion/bmw/r_1200_r/2011-en-...  40.416705 -3.703582
# 3994  http://motos.net/ocasion/kawasaki/vulcan_500_e...  40.416705 -3.703582
# 4120  http://motos.net/ocasion/bmw/f_800_r/2011-en-m...  40.416705 -3.703582
# 227   http://motos.net/ocasion/bmw/f_800_r/2011-en-m...  40.416705 -3.703582
# 2914  http://motos.net/ocasion/bmw/f_800_s/2011-en-m...  40.416705 -3.703582
# 546   http://motos.net/ocasion/bmw/r_1200_r/2011-en-...  40.416705 -3.703582
# 3522  http://motos.net/ocasion/kawasaki/vn_vulcan_80...  40.416705 -3.703582
# 2978  http://motos.net/ocasion/bmw/k_1300_r/2011-en-...  40.416705 -3.703582
# 2879  http://motos.net/ocasion/bmw/r_1200_r/2011-en-...  40.416705 -3.703582
# 280   http://motos.net/ocasion/bmw/r_1200_r/2012-en-...  40.416705 -3.703582
# 1435  http://motos.net/ocasion/kawasaki/vn_vulcan_80...  40.416705 -3.703582
# 1497  http://motos.net/ocasion/bmw/f_800_r/2012-en-m...  40.416705 -3.703582
# 1448  http://motos.net/ocasion/bmw/f_800_r/2012-en-m...  40.416705 -3.703582
# 1397  http://motos.net/ocasion/kawasaki/vn_vulcan_80...  40.416705 -3.703582
# 4000  http://motos.net/ocasion/bmw/f_800_r/2013-en-m...  40.416705 -3.703582
# 3421  http://motos.net/ocasion/bmw/k_1300_r/2013-en-...  40.416705 -3.703582
# 4876  http://motos.net/ocasion/bmw/f_800_r/2013-en-m...  40.416705 -3.703582
# 4329  http://motos.net/ocasion/bmw/k_1300_r/2013-en-...  40.416705 -3.703582
# 4960  http://motos.net/ocasion/kawasaki/vulcan_800/1...  40.416705 -3.703582
# 575   http://motos.net/ocasion/bmw/f_800_r/2013-en-m...  40.416705 -3.703582
# 4846  http://motos.net/ocasion/kawasaki/vulcan_500/1...  40.416705 -3.703582
# 2945  http://motos.net/ocasion/bmw/r_1200_r/2013-en-...  40.416705 -3.703582
# 2846  http://motos.net/ocasion/kawasaki/vn_vulcan_80...  40.416705 -3.703582
# 2230  http://motos.net/ocasion/bmw/f_800_r/2014-en-m...  40.416705 -3.703582
# 390   http://motos.net/ocasion/bmw/r_1200_r_90_anive...  40.416705 -3.703582
# 1438  http://motos.net/ocasion/bmw/r_ninet/2014-en-m...  40.416705 -3.703582
# 3139  http://motos.net/ocasion/bmw/f_800_r/2014-en-m...  40.416705 -3.703582
# 75    http://motos.net/ocasion/kawasaki/vn_900_class...  40.416705 -3.703582
#
#       brand_score  type_score  city_metric  brand_metric  type_metric  \
# 4920        356.0         280          0.0             0            0
# 3496        356.0         280          0.0             0            0
# 2538        356.0         280          0.0             0            0
# 2363        356.0         280          0.0             0            0
# 567         356.0         280          0.0             0            0
# 5162        356.0         260          0.0             0           20
# 3739        356.0         260          0.0             0           20
# 4941        356.0         260          0.0             0           20
# 3861        356.0         260          0.0             0           20
# 1175        356.0         260          0.0             0           20
# 5098        356.0         260          0.0             0           20
# 1926        356.0         260          0.0             0           20
# 3665        356.0         260          0.0             0           20
# 2245        356.0         260          0.0             0           20
# 3193        356.0         260          0.0             0           20
# 4043        356.0         260          0.0             0           20
# 806         356.0         260          0.0             0           20
# 5052        356.0         260          0.0             0           20
# 3472        356.0         260          0.0             0           20
# 1401        356.0         260          0.0             0           20
# 4604        356.0         260          0.0             0           20
# 3546        356.0         260          0.0             0           20
# 4764        356.0         260          0.0             0           20
# 3635        356.0         260          0.0             0           20
# 3099        356.0         260          0.0             0           20
# 1581        356.0         260          0.0             0           20
# 623         356.0         260          0.0             0           20
# 3343        356.0         260          0.0             0           20
# 4977        356.0         260          0.0             0           20
# 3267        356.0         260          0.0             0           20
# ...           ...         ...          ...           ...          ...
# 4942        356.0         260          0.0             0           20
# 4258        356.0         260          0.0             0           20
# 214         356.0         260          0.0             0           20
# 3994        378.0         280          0.0            22            0
# 4120        356.0         260          0.0             0           20
# 227         356.0         260          0.0             0           20
# 2914        356.0         260          0.0             0           20
# 546         356.0         260          0.0             0           20
# 3522        378.0         280          0.0            22            0
# 2978        356.0         260          0.0             0           20
# 2879        356.0         260          0.0             0           20
# 280         356.0         260          0.0             0           20
# 1435        378.0         280          0.0            22            0
# 1497        356.0         260          0.0             0           20
# 1448        356.0         260          0.0             0           20
# 1397        378.0         280          0.0            22            0
# 4000        356.0         260          0.0             0           20
# 3421        356.0         260          0.0             0           20
# 4876        356.0         260          0.0             0           20
# 4329        356.0         260          0.0             0           20
# 4960        378.0         280          0.0            22            0
# 575         356.0         260          0.0             0           20
# 4846        378.0         280          0.0            22            0
# 2945        356.0         260          0.0             0           20
# 2846        378.0         280          0.0            22            0
# 2230        356.0         260          0.0             0           20
# 390         356.0         260          0.0             0           20
# 1438        356.0         260          0.0             0           20
# 3139        356.0         260          0.0             0           20
# 75          378.0         280          0.0            22            0
#
#       year_metric  total_metric_pond
# 4920            0                0.0
# 3496            4                0.4
# 2538            4                0.4
# 2363            4                0.4
# 567             4                0.4
# 5162            0                8.0
# 3739            1                8.1
# 4941            2                8.2
# 3861            2                8.2
# 1175            3                8.3
# 5098            3                8.3
# 1926            3                8.3
# 3665            3                8.3
# 2245            3                8.3
# 3193            4                8.4
# 4043            4                8.4
# 806             4                8.4
# 5052            5                8.5
# 3472            5                8.5
# 1401            5                8.5
# 4604            6                8.6
# 3546            6                8.6
# 4764            6                8.6
# 3635            6                8.6
# 3099            6                8.6
# 1581            6                8.6
# 623             6                8.6
# 3343            6                8.6
# 4977            6                8.6
# 3267            6                8.6
# ...           ...                ...
# 4942           10                9.0
# 4258           11                9.1
# 214            11                9.1
# 3994            3                9.1
# 4120           11                9.1
# 227            11                9.1
# 2914           11                9.1
# 546            11                9.1
# 3522            3                9.1
# 2978           11                9.1
# 2879           11                9.1
# 280            12                9.2
# 1435            4                9.2
# 1497           12                9.2
# 1448           12                9.2
# 1397            5                9.3
# 4000           13                9.3
# 3421           13                9.3
# 4876           13                9.3
# 4329           13                9.3
# 4960            5                9.3
# 575            13                9.3
# 4846            5                9.3
# 2945           13                9.3
# 2846            6                9.4
# 2230           14                9.4
# 390            14                9.4
# 1438           14                9.4
# 3139           14                9.4
# 75              6                9.4
#
# [100 rows x 19 columns]

# %%
df_motos_raw_coord_brand_types.type.unique()

# %%
df_motos_raw_coord_brand_types[df_motos_raw_coord_brand_types.type=='con_marchas']

# %%
import pandas as pd
test = pd.read_csv('df_motos_raw_coord_brand_type.csv', sep=',', encoding = 'utf-8')

# %%
user_brand = int(df_rank_moto_brand[df_rank_moto_brand['brand'] == user_request[1]].brand_score)


df_rank_moto_brand.loc[df_rank_moto_brand['brand'] == user_request[1]]
